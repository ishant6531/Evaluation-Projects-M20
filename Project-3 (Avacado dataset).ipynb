# %%
#Importing Libraries 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
#Loading Avacado Database 
df=pd.read_csv("Avacado.csv")
df
# Out:
#       Unnamed: 0        Date  AveragePrice  Total Volume      4046       4225  \
# 0              0  27-12-2015          1.33      64236.62   1036.74   54454.85
# 1              1  20-12-2015          1.35      54876.98    674.28   44638.81
# 2              2  13-12-2015          0.93     118220.22    794.70  109149.67
# 3              3  06-12-2015          1.08      78992.15   1132.00   71976.41
# 4              4  29-11-2015          1.28      51039.60    941.48   43838.39
# ...          ...         ...           ...           ...       ...        ...
# 1512          10  16-10-2016          1.39     190846.01  57529.11   56366.66
# 1513          11  09-10-2016          1.51     178235.75  43325.87   52189.61
# 1514          12  02-10-2016          1.48     178410.82  46364.75   52893.38
# 1515          13  25-09-2016          1.47     189131.52  54110.79   53593.58
# 1516          14  18-09-2016          1.43     182978.30  43116.41   54193.42
#
# ...

# %%
# we are leaving first column because it is unnecessary data 
df=df.iloc[:,1:14]
df
# Out:
#             Date  AveragePrice  Total Volume      4046       4225      4770  \
# 0     27-12-2015          1.33      64236.62   1036.74   54454.85     48.16
# 1     20-12-2015          1.35      54876.98    674.28   44638.81     58.33
# 2     13-12-2015          0.93     118220.22    794.70  109149.67    130.50
# 3     06-12-2015          1.08      78992.15   1132.00   71976.41     72.58
# 4     29-11-2015          1.28      51039.60    941.48   43838.39     75.78
# ...          ...           ...           ...       ...        ...       ...
# 1512  16-10-2016          1.39     190846.01  57529.11   56366.66  17531.78
# 1513  09-10-2016          1.51     178235.75  43325.87   52189.61  19419.57
# 1514  02-10-2016          1.48     178410.82  46364.75   52893.38  16736.92
# 1515  25-09-2016          1.47     189131.52  54110.79   53593.58  17495.42
# 1516  18-09-2016          1.43     182978.30  43116.41   54193.42  16563.91
#
# ...

# %%
#Renaming Column Names
df.columns=["Date","Average Price", "Total Volume",  "PLU 4046" ,"PLU 4225" ,"PLU 4770" , "Total Bags" ,"Small Bags" ,"Large Bags" ," XLarge Bags","Types","Year" ,"Region"]
df
# Out:
#             Date  Average Price  Total Volume  PLU 4046   PLU 4225  PLU 4770  \
# 0     27-12-2015           1.33      64236.62   1036.74   54454.85     48.16
# 1     20-12-2015           1.35      54876.98    674.28   44638.81     58.33
# 2     13-12-2015           0.93     118220.22    794.70  109149.67    130.50
# 3     06-12-2015           1.08      78992.15   1132.00   71976.41     72.58
# 4     29-11-2015           1.28      51039.60    941.48   43838.39     75.78
# ...          ...            ...           ...       ...        ...       ...
# 1512  16-10-2016           1.39     190846.01  57529.11   56366.66  17531.78
# 1513  09-10-2016           1.51     178235.75  43325.87   52189.61  19419.57
# 1514  02-10-2016           1.48     178410.82  46364.75   52893.38  16736.92
# 1515  25-09-2016           1.47     189131.52  54110.79   53593.58  17495.42
# 1516  18-09-2016           1.43     182978.30  43116.41   54193.42  16563.91
#
# ...

# %%
# Name of the columns
df.columns
# Out:
# Index(['Date', 'Average Price', 'Total Volume', 'PLU 4046', 'PLU 4225',
#        'PLU 4770', 'Total Bags', 'Small Bags', 'Large Bags', ' XLarge Bags',
#        'Types', 'Year', 'Region'],
#       dtype='object')

# %%
# Shape of the database 
df.shape
# Out:
# (1517, 13)

# %%
#Information of the database
df.info
# Out:
# <bound method DataFrame.info of             Date  Average Price  Total Volume  PLU 4046   PLU 4225  PLU 4770  \
# 0     27-12-2015           1.33      64236.62   1036.74   54454.85     48.16
# 1     20-12-2015           1.35      54876.98    674.28   44638.81     58.33
# 2     13-12-2015           0.93     118220.22    794.70  109149.67    130.50
# 3     06-12-2015           1.08      78992.15   1132.00   71976.41     72.58
# 4     29-11-2015           1.28      51039.60    941.48   43838.39     75.78
# ...          ...            ...           ...       ...        ...       ...
# 1512  16-10-2016           1.39     190846.01  57529.11   56366.66  17531.78
# 1513  09-10-2016           1.51     178235.75  43325.87   52189.61  19419.57
# 1514  02-10-2016           1.48     178410.82  46364.75   52893.38  16736.92
# 1515  25-09-2016           1.47     189131.52  54110.79   53593.58  17495.42
# 1516  18-09-2016           1.43     182978.30  43116.41   54193.42  16563.91
#
# ...

# %%
df.describe()
# Out:
#        Average Price  Total Volume      PLU 4046      PLU 4225      PLU 4770  \
# count    1517.000000  1.517000e+03  1.517000e+03  1.517000e+03  1.517000e+03
# mean        1.074990  1.601879e+06  6.464387e+05  6.114375e+05  5.040550e+04
# std         0.188891  4.433143e+06  1.947614e+06  1.672906e+06  1.377812e+05
# min         0.490000  3.875074e+04  4.677200e+02  1.783770e+03  0.000000e+00
# 25%         0.980000  1.474700e+05  2.040034e+04  4.147606e+04  9.112500e+02
# 50%         1.080000  4.027919e+05  8.175117e+04  1.186649e+05  7.688170e+03
# 75%         1.190000  9.819751e+05  3.775785e+05  4.851503e+05  2.916730e+04
# max         1.680000  4.465546e+07  1.893304e+07  1.895648e+07  1.381516e+06
#
#          Total Bags    Small Bags    Large Bags    XLarge Bags         Year
# count  1.517000e+03  1.517000e+03  1.517000e+03    1517.000000  1517.000000
# mean   2.935974e+05  2.487736e+05  4.264205e+04    2181.771074  2015.162821
# ...

# %%
#datatypes
df.dtypes
# Out:
# Date              object
# Average Price    float64
# Total Volume     float64
# PLU 4046         float64
# PLU 4225         float64
# PLU 4770         float64
# Total Bags       float64
# Small Bags       float64
# Large Bags       float64
#  XLarge Bags     float64
# Types             object
# Year               int64
# Region            object
# dtype: object

# %%
#finding null values in the database
df.isnull().sum()
# Out:
# Date             0
# Average Price    0
# Total Volume     0
# PLU 4046         0
# PLU 4225         0
# PLU 4770         0
# Total Bags       0
# Small Bags       0
# Large Bags       0
#  XLarge Bags     0
# Types            0
# Year             0
# Region           0
# dtype: int64

# %%
#Making Heatmap of null values
sns.heatmap(df.isnull())

# %%
#Finding Correlation of the variables
df.corr()
# Out:
#                Average Price  Total Volume  PLU 4046  PLU 4225  PLU 4770  \
# Average Price       1.000000     -0.140470 -0.190096 -0.092084 -0.100567
# Total Volume       -0.140470      1.000000  0.985568  0.987154  0.934347
# PLU 4046           -0.190096      0.985568  1.000000  0.951952  0.898570
# PLU 4225           -0.092084      0.987154  0.951952  1.000000  0.927757
# PLU 4770           -0.100567      0.934347  0.898570  0.927757  1.000000
# Total Bags         -0.111597      0.967689  0.930395  0.951779  0.926405
# Small Bags         -0.097682      0.960642  0.922278  0.943988  0.923607
# Large Bags         -0.177480      0.910226  0.884229  0.900496  0.840523
#  XLarge Bags       -0.048284      0.521717  0.474063  0.504718  0.646053
# Year                0.178683     -0.004189 -0.040439 -0.007254  0.029222
#
#                Total Bags  Small Bags  Large Bags   XLarge Bags      Year
# Average Price   -0.111597   -0.097682   -0.177480     -0.048284  0.178683
# ...

# %%
# Making Heatmap of correlation
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),annot=True)

# %% [markdown]
# # Bivariate Analysis

# %%
# Making Barplot of  Average price at which single Avocado sold in Year 2016 and 2015
plt.figure(figsize=(8,5))
pd =sns.barplot(x = "Year", y = "Average Price",  data=df)
for p in pd.patches:
    pd.annotate(format(p.get_height(), '.1f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   size=18,
                   xytext = (0, -100), 
                   textcoords = 'offset points')

plt.xlabel("Year" , size=15)
plt.ylabel("Average Price" ,size=15)
plt.title (" Average price of single Avocado sold in different years" , size=15)
plt.show()
#conclusion:- In 2016 average price of single avocado sold is more than in 2015.

# %%
# Making Barplot of total volume of Avocado sold in 2016 and 2015
plt.figure(figsize=(8,6))
pd =sns.barplot(x = "Year", y = "Total Volume",  data=df)
for p in pd.patches:
    pd.annotate(format(p.get_height(), '.0f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   size=18,
                   xytext = (0, -100), 
                   textcoords = 'offset points')

plt.xlabel("Year" , size=15)
plt.ylabel("Total Volume" ,size=15)
plt.title (" Total volume of Avocado sold in different Years" , size=15)
plt.show()
#Total volume of avocado sold is more in 2015 than 2016.

# %%
datasorted=df.groupby("Region").mean()
datasorted=datasorted.sort_values("Average Price",ascending=False)

# %%
datasorted.head(10)
# Out:
#                      Average Price  Total Volume       PLU 4046      PLU 4225  \
# Region
# Syracuse                  1.347368  4.857841e+04    1105.586842  2.469991e+04
# Charlotte                 1.311613  1.762781e+05   43324.148387  4.502836e+04
# BuffaloRochester          1.301569  1.321844e+05    1576.289216  6.379754e+04
# Philadelphia              1.293846  3.849221e+05   19337.481538  2.547542e+05
# StLouis                   1.260000  1.944995e+05  110053.169375  3.720367e+04
# NewYork                   1.248636  1.362973e+06   20449.793409  1.052267e+06
# Albany                    1.238657  7.629020e+04    1732.056418  6.185452e+04
# Northeast                 1.236667  3.465864e+06  107352.851667  2.427952e+06
# Chicago                   1.214783  8.118822e+05   38144.204348  5.681663e+05
# HartfordSpringfield       1.209231  2.685772e+05    4445.064615  2.196154e+05
#
#                           PLU 4770     Total Bags     Small Bags  \
# Region
# ...

# %%
# Making barplot between average price and region 
plt.figure(figsize=(20,15))
sns.barplot(x=datasorted.index,y=datasorted["Average Price"])
plt.xticks(rotation= 90)
plt.xlabel('States', size= 20 )
plt.ylim(0,1.8)
plt.ylabel('Average Price' , size= 20)
plt.title('Average Price of Single Avocados in different   Region' , size= 20)
#conclusion :- Syracuse has the maximum average price  of Single  Avocados comparing all other region.
# Out:
# Text(0.5, 1.0, 'Average Price of Single Avocados in different   Region')

# %%
datasorted1 =datasorted.sort_values("Total Volume",ascending=False)

# %%
datasorted1.head(10)
# Out:
#               Average Price  Total Volume      PLU 4046      PLU 4225  \
# Region
# TotalUS            1.011600  3.293714e+07  1.422580e+07  1.243888e+07
# California         1.055921  6.035277e+06  2.410017e+06  1.984823e+06
# West               0.940833  5.574939e+06  2.348945e+06  2.040127e+06
# SouthCentral       0.818718  5.496995e+06  3.077958e+06  1.625283e+06
# Northeast          1.236667  3.465864e+06  1.073529e+05  2.427952e+06
# GreatLakes         1.107222  3.276358e+06  5.652089e+05  1.720079e+06
# Southeast          1.091111  3.055239e+06  2.195695e+06  2.826350e+05
# LosAngeles         0.863333  2.732180e+06  1.849780e+06  5.559236e+05
# Midsouth           1.081111  2.355099e+06  5.020956e+05  1.163150e+06
# Plains             1.051667  1.672975e+06  9.263925e+05  4.891971e+05
#
#                    PLU 4770    Total Bags    Small Bags     Large Bags  \
# Region
# TotalUS       950091.078000  5.322368e+06  4.519090e+06  779546.107600
# ...

# %%
# Making barplot between Total volume of avocado sold and region 
plt.figure(figsize=(20,15))
sns.barplot(x=datasorted1.index,y=datasorted1["Total Volume"])

plt.xticks(rotation= 90)
plt.xlabel('States', size= 20 )
plt.ylim(0,40000000)
plt.ylabel('Total  Volume  of Avocado sold ( In crore)' , size= 20)
plt.title('Total Volume of Avocados sold   by different Region' , size= 20)


#conclusion :- In TotalUS  maximum Avocado sold comparing all region.
# Out:
# Text(0.5, 1.0, 'Total Volume of Avocados sold   by different Region')

# %% [markdown]
# # Multivariate Analysis

# %%
# Making Histrogram of all variables
df.hist(figsize=(20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002080A764A08>,
# ...
#       dtype=object)

# %%
# Making Boxplot of all variables 
df.plot(kind='box',subplots=True,layout=(4,5),figsize=(25,25))
# Out:
# Average Price        AxesSubplot(0.125,0.71587;0.133621x0.16413)
# Total Volume      AxesSubplot(0.285345,0.71587;0.133621x0.16413)
# PLU 4046           AxesSubplot(0.44569,0.71587;0.133621x0.16413)
# PLU 4225          AxesSubplot(0.606034,0.71587;0.133621x0.16413)
# PLU 4770          AxesSubplot(0.766379,0.71587;0.133621x0.16413)
# Total Bags          AxesSubplot(0.125,0.518913;0.133621x0.16413)
# Small Bags       AxesSubplot(0.285345,0.518913;0.133621x0.16413)
# Large Bags        AxesSubplot(0.44569,0.518913;0.133621x0.16413)
#  XLarge Bags     AxesSubplot(0.606034,0.518913;0.133621x0.16413)
# Year             AxesSubplot(0.766379,0.518913;0.133621x0.16413)
# dtype: object

# %%
# Making Pairplot
plt.figure(figsize=(20,20))
sns.pairplot(df)

# %% [markdown]
# # Univariate analysis

# %%
# Making Distribution plot of Average Price

plt.figure(figsize=(15,8))
sns.distplot(df["Average Price"], bins=50 ,kde=False , fit=norm )
plt.xlabel("Average Price", Size=15 )
plt.ylabel("Frequency" , Size=15)
plt.show()

# %%
df["Types"].unique()
#Here in "types" column their is only one type of data so we will drop the column
# Out:
# array(['conventional'], dtype=object)

# %%
# droping types and dates column 
df1=df.drop(["Types","Date"],axis=1)

# %%
df1
# Out:
#       Average Price  Total Volume  PLU 4046   PLU 4225  PLU 4770  Total Bags  \
# 0              1.33      64236.62   1036.74   54454.85     48.16     8696.87
# 1              1.35      54876.98    674.28   44638.81     58.33     9505.56
# 2              0.93     118220.22    794.70  109149.67    130.50     8145.35
# 3              1.08      78992.15   1132.00   71976.41     72.58     5811.16
# 4              1.28      51039.60    941.48   43838.39     75.78     6183.95
# ...             ...           ...       ...        ...       ...         ...
# 1512           1.39     190846.01  57529.11   56366.66  17531.78    59418.46
# 1513           1.51     178235.75  43325.87   52189.61  19419.57    63300.70
# 1514           1.48     178410.82  46364.75   52893.38  16736.92    62415.77
# 1515           1.47     189131.52  54110.79   53593.58  17495.42    63931.73
# 1516           1.43     182978.30  43116.41   54193.42  16563.91    69104.56
#
# ...

# %%
#Using label Encoder to convert character data into numbers 
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
list1=["Year","Region"]
for val in list1:
    df1[val]=le.fit_transform(df1[val].astype(str))

# %%
#calculating Z score
from scipy.stats import zscore
z=np.abs(zscore(df1))
z
# Out:
# array([[1.35048079, 0.34696593, 0.33149016, ..., 0.29272731, 0.44100815,
#         1.3143384 ],
#        [1.45639674, 0.34907791, 0.33167633, ..., 0.29272731, 0.44100815,
#         1.3143384 ],
#        [0.76783831, 0.33478463, 0.33161448, ..., 0.29272731, 0.44100815,
#         1.3143384 ],
#        ...,
#        [2.14485045, 0.32120275, 0.30820887, ..., 0.1820374 , 2.26753179,
#         0.88028586],
#        [2.09189247, 0.31878364, 0.30423037, ..., 0.29272731, 2.26753179,
#         0.88028586],
#        [1.88006056, 0.3201721 , 0.30987728, ..., 0.29272731, 2.26753179,
#         0.88028586]])

# %%
# Removing Outliners 
from scipy import stats
df1=df1[(z<3).all(axis=1)]

# %%
df1
# Out:
#       Average Price  Total Volume  PLU 4046   PLU 4225  PLU 4770  Total Bags  \
# 0              1.33      64236.62   1036.74   54454.85     48.16     8696.87
# 1              1.35      54876.98    674.28   44638.81     58.33     9505.56
# 2              0.93     118220.22    794.70  109149.67    130.50     8145.35
# 3              1.08      78992.15   1132.00   71976.41     72.58     5811.16
# 4              1.28      51039.60    941.48   43838.39     75.78     6183.95
# ...             ...           ...       ...        ...       ...         ...
# 1512           1.39     190846.01  57529.11   56366.66  17531.78    59418.46
# 1513           1.51     178235.75  43325.87   52189.61  19419.57    63300.70
# 1514           1.48     178410.82  46364.75   52893.38  16736.92    62415.77
# 1515           1.47     189131.52  54110.79   53593.58  17495.42    63931.73
# 1516           1.43     182978.30  43116.41   54193.42  16563.91    69104.56
#
# ...

# %% [markdown]
# # Splitting Data into Input and Target

# %%
x=df1.iloc[:,1:11]
x
# Out:
#       Total Volume  PLU 4046   PLU 4225  PLU 4770  Total Bags  Small Bags  \
# 0         64236.62   1036.74   54454.85     48.16     8696.87     8603.62
# 1         54876.98    674.28   44638.81     58.33     9505.56     9408.07
# 2        118220.22    794.70  109149.67    130.50     8145.35     8042.21
# 3         78992.15   1132.00   71976.41     72.58     5811.16     5677.40
# 4         51039.60    941.48   43838.39     75.78     6183.95     5986.26
# ...            ...       ...        ...       ...         ...         ...
# 1512     190846.01  57529.11   56366.66  17531.78    59418.46    48823.53
# 1513     178235.75  43325.87   52189.61  19419.57    63300.70    54704.14
# 1514     178410.82  46364.75   52893.38  16736.92    62415.77    53332.61
# 1515     189131.52  54110.79   53593.58  17495.42    63931.73    55653.47
# 1516     182978.30  43116.41   54193.42  16563.91    69104.56    57456.21
#
#       Large Bags   XLarge Bags  Year  Region
# ...

# %%
y=df1.iloc[:,0]
y
# Out:
# 0       1.33
# 1       1.35
# 2       0.93
# 3       1.08
# 4       1.28
#         ...
# 1512    1.39
# 1513    1.51
# 1514    1.48
# 1515    1.47
# 1516    1.43
# Name: Average Price, Length: 1436, dtype: float64

# %%
# Standard scaling the data 
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
print(scaler.fit(x))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
x.skew()
# Out:
# Total Volume    2.704085
# PLU 4046        3.120756
# PLU 4225        2.367429
# PLU 4770        3.331191
# Total Bags      4.165747
# Small Bags      4.410267
# Large Bags      3.518056
#  XLarge Bags    5.118965
# Year            2.004439
# Region          0.276276
# dtype: float64

# %%
#Reducing  Skewness
import numpy as np
for col in x.columns:
    if x.skew().loc[col]>0.55:
         x[col]=np.log1p(x[col])

# %%
x.skew()
# Out:
# Total Volume    0.462899
# PLU 4046       -0.270283
# PLU 4225        0.011359
# PLU 4770       -0.449713
# Total Bags      0.378673
# Small Bags      0.420856
# Large Bags     -0.979047
#  XLarge Bags    0.851740
# Year            2.004439
# Region          0.276276
# dtype: float64

# %%
#Reducing  Skewness
import numpy as np
for col in x.columns:
    if x.skew().loc[col]>0.55:
         x[col]=np.log1p(x[col])

# %%
x.skew()
# Out:
# Total Volume    0.462899
# PLU 4046       -0.270283
# PLU 4225        0.011359
# PLU 4770       -0.449713
# Total Bags      0.378673
# Small Bags      0.420856
# Large Bags     -0.979047
#  XLarge Bags    0.451310
# Year            2.004439
# Region          0.276276
# dtype: float64

# %% [markdown]
# # Importing Necessary libraries

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet

# %%
def maxr2_score(regr,x,y):
    max_r_score=0
    for i in range(42,100):
        x_train,x_test,y_train,y_test=train_test_split(x,y,random_state= i ,test_size=0.20)
        regr.fit(x,y)
        y_pred=regr.predict(x_test)
        r2_scr=r2_score(y_test,y_pred)
        if r2_scr>max_r_score:
            max_r_score=r2_scr
            final_i=i
    print(" We are getting maximum  r2 score corresponding to",final_i,"is",max_r_score)
    return final_i

# %%
#Finding best random state value for Linear Regression
from sklearn.linear_model import LinearRegression
lreg=LinearRegression()
r_state=maxr2_score(lreg,x,y)
# Out:
#  We are getting maximum  r2 score corresponding to 57 is 0.4774326729192693

# %%
from sklearn.model_selection import cross_val_score
print("Mean r2 score for Linear Regression:",cross_val_score(lreg,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for Linear Regression",cross_val_score(lreg,x,y,cv=5,scoring="r2").std())
print()
# Out:
# Mean r2 score for Linear Regression: 0.04007761221154869
# standard deviation in r2 score for Linear Regression 0.3420685848748133

# %% [markdown]
# # Using GridSearchCv to find best parameters of different algorithims

# %%
sv=SVR()
parameters={'kernel':('linear','rbf','poly','sigmoid'),'C':[1,10]}
gd=GridSearchCV(sv,parameters)
gd.fit(x,y)
print(gd.best_params_)
print("\n")


knn=KNeighborsRegressor()
parameters={'n_neighbors':(5,20)}
gd=GridSearchCV(knn,parameters)
gd.fit(x,y)
print(gd.best_params_)
print("\n")

dtc=DecisionTreeRegressor()
parameters={'criterion':('mse', 'friedman_mse', 'mae')}
gd=GridSearchCV(dtc,parameters)
gd.fit(x,y)
print(gd.best_params_)
print("\n")


lsreg=Lasso()
parameters={"alpha":[0.001,0.01,0.1,1]}
gd=GridSearchCV(lsreg,parameters)
gd.fit(x,y)
print(gd.best_params_)
print("\n")

from sklearn.linear_model import ElasticNet
enr=ElasticNet()
parametors={"alpha":[0.001,0.01,0.1,1]}
gd=GridSearchCV(enr,parametors,cv=10)
gd.fit(x,y)
gd.best_params_
# Out:
# {'C': 1, 'kernel': 'linear'}
#
#
# {'n_neighbors': 5}
#
#
# {'criterion': 'friedman_mse'}
#
#
# {'alpha': 0.1}
# {'alpha': 0.1}

# %%
#Finding best random state value for SVR
sv=SVR( C = 1,  kernel = "poly" )
i=maxr2_score(sv,x,y)
# Out:
#  We are getting maximum  r2 score corresponding to 73 is 0.5763552118285851

# %%
from sklearn.model_selection import cross_val_score
print("Mean r2 score for SVR:",cross_val_score(sv,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for SVR",cross_val_score(sv,x,y,cv=5,scoring="r2").std())
print()
# Out:
# Mean r2 score for SVR: -0.26827171516480314
# standard deviation in r2 score for SVR 0.6121780272741396

# %%
#Finding best random state value for KNeighbors Regressor 
knn=KNeighborsRegressor(n_neighbors=20)
i=maxr2_score(knn,x,y)
# Out:
#  We are getting maximum  r2 score corresponding to 63 is 0.7827467602482969

# %%
#Finding cross value score 
from sklearn.model_selection import cross_val_score
print("Mean r2 score for KNeighbor  Regression:",cross_val_score(knn,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for KNeighbor   Regression",cross_val_score(knn,x,y,cv=5,scoring="r2").std())
# Out:
# Mean r2 score for KNeighbor  Regression: -0.5238602350854361
# standard deviation in r2 score for KNeighbor   Regression 0.8316614371983263

# %%
## Finding best random state value for  Lasso Regressor
lsreg=Lasso(alpha=0.1)
i=maxr2_score(lsreg,x,y)
# Out:
#  We are getting maximum  r2 score corresponding to 57 is 0.2748978588376918

# %%
from sklearn.model_selection import cross_val_score
print("Mean r2 score for Lasso Regression:",cross_val_score(lsreg,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for Lasso Regression",cross_val_score(lsreg,x,y,cv=5,scoring="r2").std())
# Out:
# Mean r2 score for Lasso Regression: 0.10677757562632965
# standard deviation in r2 score for Lasso Regression 0.048481383613769816

# %%
# Finding best random state value for elastic net 
enr=ElasticNet(alpha =0.1)
i=maxr2_score(enr,x,y)
# Out:
#  We are getting maximum  r2 score corresponding to 57 is 0.3348505216338731

# %%
print("Mean r2 score for elastic net :",cross_val_score(enr,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for elastic net ",cross_val_score(enr,x,y,cv=5,scoring="r2").std())
# Out:
# Mean r2 score for elastic net : 0.12258012534839358
# standard deviation in r2 score for elastic net  0.11436714506667171

# %%
# Finding best pararmeters for Random forest regressor using grid searchcv
from sklearn.ensemble import RandomForestRegressor
rfr=RandomForestRegressor()
parameters={"n_estimators":[10,50,100,150,200 ,250,300 ,400, 500],"max_features": ["auto", "sqrt", "log2"]}
clf=GridSearchCV(rfr,parameters,cv=5)
clf.fit(x,y)
clf.best_params_
# Out:
# {'max_features': 'log2', 'n_estimators': 250}

# %%
# Finding best random state value for Randomforest Regressor
rfr=RandomForestRegressor(max_features = 'log2', n_estimators = 250)
i=maxr2_score(rfr,x,y)
# Out:
#  We are getting maximum  r2 score corresponding to 88 is 0.9849264776478523

# %%
print("Mean r2 score for Randomforest Regressor:",cross_val_score(rfr,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for Randomforest Regressor",cross_val_score(rfr,x,y,cv=5,scoring="r2").std())
# Out:
# Mean r2 score for Randomforest Regressor: 0.20691192290126498
# standard deviation in r2 score for Randomforest Regressor 0.3076358480120702

# %%
# Finding best pararmeters for  AdaBoostRegressor using grid searchcv
from sklearn.ensemble import AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
ada_reg=AdaBoostRegressor()
parameters={"learning_rate":[0.001,0.01,0.1,1],"n_estimators":[10,50,100,150,200,250,500],"base_estimator":[lreg,knn,dtc,lsreg,enr]}
clg=GridSearchCV(ada_reg,parameters,cv=5)
clg.fit(x,y)
clg.best_params_
# Out:
# {'base_estimator': DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best'),
#  'learning_rate': 1,
#  'n_estimators': 100}

# %%
ada_reg=AdaBoostRegressor(base_estimator=DecisionTreeRegressor(),learning_rate=1,n_estimators=100)
print("Mean r2 score for ada boosting regression:",cross_val_score(ada_reg,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2score for ada boosting regression",cross_val_score(ada_reg,x,y,cv=5,scoring="r2").std())
# Out:
# Mean r2 score for ada boosting regression: 0.17563252982358385
# standard deviation in r2score for ada boosting regression 0.3457260454417209

# %% [markdown]
# # We have selected Random forest regressor as our final model because we are getting better r2 score and cross value score from all  other models tested.

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=88,test_size=0.20)
rfr=RandomForestRegressor(max_features = 'log2', n_estimators = 250)
rfr.fit(x,y)
y_pred=rfr.predict(x_test)

# %%
import numpy as np
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
print("RMSE is: ",np.sqrt(mean_squared_error(y_test,y_pred)))
print("r2_score is:",r2_score(y_test,y_pred))
print('MSE is :' ,(mean_squared_error(y_test,y_pred)))
# Out:
# RMSE is:  0.02383594589410436
# r2_score is: 0.984787925873524
# MSE is : 0.0005681523166666705

# %% [markdown]
# # Saving the model

# %%
from sklearn.externals import joblib
joblib.dump(rfr,"Avocado.pkl")
# Out:
# ['Avocado.pkl']
